# %% [markdown]
# <a href="https://colab.research.google.com/github/faijulislam45f-netizen/-faijul-/blob/main/chap00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'name':['faijul', 'arbaz'],
        'age':[30,25],
        'id':[1, 3]}
df = pd.DataFrame(data)
print(df)
# Out:
#      name  age  id
# 0  faijul   30   1
# 1   arbaz   25   3
